# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"Bengaluru_House_Data.csv", encoding="unicode_escape")
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.tail(20)
# Out:
#                   area_type   availability               location       size  \
# 13300            Plot  Area  Ready To Move          Hosakerehalli  5 Bedroom
# 13301  Super built-up  Area  Ready To Move               Kothanur      3 BHK
# 13302  Super built-up  Area  Ready To Move   Annaiah Reddy Layout      2 BHK
# 13303            Plot  Area  Ready To Move         Vidyaranyapura  5 Bedroom
# 13304  Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13305          Carpet  Area  Ready To Move               Hulimavu      1 BHK
# 13306            Plot  Area  Ready To Move  Rajarajeshwari Nagara  4 Bedroom
# 13307        Built-up  Area  Ready To Move           Billekahalli      3 BHK
# 13308        Built-up  Area  Ready To Move      Bannerghatta Road      3 BHK
# 13309  Super built-up  Area  Ready To Move           Yeshwanthpur      3 BHK
# 13310  Super built-up  Area  Ready To Move           Rachenahalli      2 BHK
# ...

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
data["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
data["location"].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
data["society"].unique()
# Out:
# array(['Coomee ', 'Theanmp', nan, ..., 'SJovest', 'ThhtsV ', 'RSntsAp'],
#       dtype=object)

# %%
data["bath"].unique()
# Out:
# array([ 2.,  5.,  3.,  4.,  6.,  1.,  9., nan,  8.,  7., 11., 10., 14.,
#        27., 12., 16., 40., 15., 13., 18.])

# %%
data["balcony"].unique()
# Out:
# array([ 1.,  3., nan,  2.,  0.])

# %%
data["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
data["total_sqft"].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
data["availability"].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
data1=data.drop(["society","availability"], axis=1)

# %%
data1.head()
# Out:
#               area_type                  location       size total_sqft  bath  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK       1056   2.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2        Built-up  Area               Uttarahalli      3 BHK       1440   2.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK       1521   3.0
# 4  Super built-up  Area                  Kothanur      2 BHK       1200   2.0
#
#    balcony   price
# 0      1.0   39.07
# 1      3.0  120.00
# 2      3.0   62.00
# 3      1.0   95.00
# 4      1.0   51.00

# %%
data1.isnull().sum()
# Out:
# area_type       0
# location        1
# size           16
# total_sqft      0
# bath           73
# balcony       609
# price           0
# dtype: int64

# %%
data1.dropna(subset=["size","bath"], inplace=True)

# %%
data1.isnull().sum()
# Out:
# area_type       0
# location        1
# size            0
# total_sqft      0
# bath            0
# balcony       536
# price           0
# dtype: int64

# %%
data1["balcony"].fillna(method='ffill' , inplace= True)

# %%
data1.isnull().sum()
# Out:
# area_type     0
# location      1
# size          0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# dtype: int64

# %%
data1["bhk"]=data1["size"].str.extract('(\d+)').astype(int)

# %%
data1["bhk"].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18])

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
data1[~data1['total_sqft'].apply(is_float)].head(10)
# Out:
#                 area_type            location       size      total_sqft  \
# 30   Super built-up  Area           Yelahanka      4 BHK     2100 - 2850
# 122  Super built-up  Area              Hebbal      4 BHK     3067 - 8156
# 137  Super built-up  Area  8th Phase JP Nagar      2 BHK     1042 - 1105
# 165  Super built-up  Area            Sarjapur      2 BHK     1145 - 1340
# 188  Super built-up  Area            KR Puram      2 BHK     1015 - 1540
# 410  Super built-up  Area             Kengeri      1 BHK  34.46Sq. Meter
# 549  Super built-up  Area         Hennur Road      2 BHK     1195 - 1440
# 648        Built-up  Area             Arekere  9 Bedroom       4125Perch
# 661  Super built-up  Area           Yelahanka      2 BHK     1120 - 1145
# 672        Built-up  Area        Bettahalsoor  4 Bedroom     3090 - 5002
#
#      bath  balcony    price  bhk
# 30    4.0      0.0  186.000    4
# 122   4.0      0.0  477.000    4
# 137   2.0      0.0   54.005    2
# ...

# %% [markdown]
# Above shows that total_sqft can be a range (e.g. 2100-2850). For such case we can just take average of min and max value in the range. There are other cases such as 34.46Sq. Meter which one can convert to square ft using unit conversion. I am going to convert that values also in sqare fit

# %%
import re
def convert_values_sq_ft(value):
    if re.match(r'\d+-\d+',value):
        start, end =map(int, value.split('-'))
        return (start + end)/2
    
    elif "Sq.Meter" in value :
        value= value.replace("Sq.Meter","").strip()
        return float(value)*10.7639
    
    elif "Perch" in value :
        value= value.replace("Perch","").strip()
        return float(value)*272.25
    elif "Sq.Feet" in value :
        value= value.replace("Sq.Feet","").strip()
        return int(value)
    elif value.isdigit():
        return int(value)
    else:
        return None

# %%
data1["total_sqft"]=data1["total_sqft"].apply(convert_values_sq_ft)

# %%
data1[~data1['total_sqft'].apply(is_float)].head(10)
# Out:
# Empty DataFrame
# Columns: [area_type, location, size, total_sqft, bath, balcony, price, bhk]
# Index: []

# %%
data1["total_sqft"].unique()
# Out:
# array([1056., 2600., 1440., ..., 2758.,  774., 4689.])

# %%
data1["price_per_sq_fit"]=data1["price"]*100000/data1["total_sqft"]

# %%
data1.head()
# Out:
#               area_type                  location       size  total_sqft  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2        Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4  Super built-up  Area                  Kothanur      2 BHK      1200.0
#
#    bath  balcony   price  bhk  price_per_sq_fit
# 0   2.0      1.0   39.07    2       3699.810606
# 1   5.0      3.0  120.00    4       4615.384615
# 2   2.0      3.0   62.00    3       4305.555556
# 3   3.0      1.0   95.00    3       6245.890861
# 4   2.0      1.0   51.00    2       4250.000000

# %% [raw]
# As a data scientist when you have a conversation with your business manager (who has expertise in real estate), he will tell you that normally square ft per bedroom is 300 (i.e. 2 bhk apartment is minimum 600 sqft. If you have for example 400 sqft apartment with 2 bhk than that seems suspicious and can be removed as an outlier. We will remove such outliers by keeping our minimum thresold per bhk to be 300 sqft

# %%
data1[data1.total_sqft/data1.bhk<300].head()
# Out:
#      area_type             location       size  total_sqft  bath  balcony  \
# 9   Plot  Area         Gandhi Bazar  6 Bedroom      1020.0   6.0      1.0
# 45  Plot  Area           HSR Layout  8 Bedroom       600.0   9.0      2.0
# 58  Plot  Area        Murugeshpalya  6 Bedroom      1407.0   4.0      1.0
# 68  Plot  Area  Devarachikkanahalli  8 Bedroom      1350.0   7.0      0.0
# 70  Plot  Area          Double Road  3 Bedroom       500.0   3.0      2.0
#
#     price  bhk  price_per_sq_fit
# 9   370.0    6      36274.509804
# 45  200.0    8      33333.333333
# 58  150.0    6      10660.980810
# 68   85.0    8       6296.296296
# 70  100.0    3      20000.000000

# %% [raw]
# Check above data points. We have 6 bhk apartment with 1020 sqft. Another one is 8 bhk and total sqft is 600. These are clear data errors that can be removed safely

# %%
data2 = data1[~(data1.total_sqft/data1.bhk<300)]

# %%
data2.price_per_sq_fit.describe()
# Out:
# count     12227.000000
# mean       6311.522143
# std        4187.284676
# min          23.596850
# 25%        4202.889476
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sq_fit, dtype: float64

# %% [raw]
# Here we find that min price per sqft is 267 rs/sqft whereas max is 12000000, this shows a wide variation in property prices. We should remove outliers per location using mean and one standard deviation

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sq_fit)
        st = np.std(subdf.price_per_sq_fit)
        reduced_df = subdf[(subdf.price_per_sq_fit>(m-st)) & (subdf.price_per_sq_fit<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
data3 = remove_pps_outliers(data2)
data3.shape
# Out:
# (9090, 9)

# %%
def plot_scatter_chart(data3,location):
    bhk2 = data3[(data3.location==location) & (data3.bhk==2)]
    bhk3 = data3[(data3.location==location) & (data3.bhk==3)]
    plt.figure(figsize=(15,10))
    plt.scatter(bhk2.price_per_sq_fit,bhk2.price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.price_per_sq_fit,bhk3.price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(data3,"Rajaji Nagar")

# %% [raw]
# We should also remove properties where for same location, the price of (for example) 3 bedroom apartment is less than 2 bedroom apartment (with same square ft area). What we will do is for a given location, we will build a dictionary of stats per bh

# %%
def remove_bhk_outliers(data3):
    exclude_indices = np.array([])
    for location, location_df in data3.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sq_fit),
                'std': np.std(bhk_df.price_per_sq_fit),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sq_fit<(stats['mean'])].index.values)
    return data3.drop(exclude_indices,axis='index')
data4 = remove_bhk_outliers(data3)

# %%
plot_scatter_chart(data4,"Rajaji Nagar")

# %%
data4.bath.unique()
# Out:
# array([ 3.,  2.,  1.,  4.,  5.,  8.,  9.,  6., 14.,  7., 12.])

# %%
plt.figure(figsize=(8, 6))
plt.hist(x="bath", data=data4)
plt.show()

# %%
data4[data4.bath>8]
# Out:
#                  area_type               location       size  total_sqft  \
# 100           Carpet  Area  4th Block Koramangala      9 BHK      4500.0
# 764             Plot  Area          BTM 1st Stage  9 Bedroom      3300.0
# 4319        Built-up  Area               KR Puram      9 BHK      4600.0
# 5834  Super built-up  Area            Mico Layout      9 BHK      5000.0
# 6058  Super built-up  Area         Neeladri Nagar     10 BHK      4000.0
# 6520        Built-up  Area  Raja Rajeshwari Nagar  9 Bedroom      3600.0
# 7292  Super built-up  Area      Sathya Sai Layout      6 BHK     11338.0
# 9012            Plot  Area                 Yemlur  8 Bedroom     12000.0
#
#       bath  balcony   price  bhk  price_per_sq_fit
# 100    9.0      3.0   500.0    9      11111.111111
# 764   14.0      2.0   500.0    9      15151.515152
# 4319   9.0      2.0   200.0    9       4347.826087
# 5834   9.0      3.0   210.0    9       4200.000000
# 6058  12.0      2.0   160.0   10       4000.000000
# ...

# %%
data4[data4.bath>data4.bhk+1]
# Out:
#                  area_type                location       size  total_sqft  \
# 83              Plot  Area    2nd Stage Nagarbhavi  6 Bedroom      3000.0
# 84              Plot  Area    2nd Stage Nagarbhavi  6 Bedroom      2400.0
# 88              Plot  Area  3rd Block Banashankari  6 Bedroom      2400.0
# 102   Super built-up  Area   4th Block Koramangala      4 BHK      3400.0
# 106   Super built-up  Area      4th Phase JP Nagar      2 BHK       600.0
# ...                    ...                     ...        ...         ...
# 8241            Plot  Area             Vijayanagar  4 Bedroom      2100.0
# 8421  Super built-up  Area              Whitefield      3 BHK      3850.0
# 8484  Super built-up  Area              Whitefield      3 BHK      2700.0
# 8572  Super built-up  Area              Whitefield      4 BHK      4003.0
# 8939  Super built-up  Area               Yelahanka      4 BHK      3019.0
#
#       bath  balcony  price  bhk  price_per_sq_fit
# ...

# %% [raw]
# Again the business manager has a conversation with you (i.e. a data scientist) that if you have 4 bedroom home and even if you have bathroom in all 4 rooms plus one guest bathroom, you will have total bath = total bed + 1. Anything above that is an outlier or a data error and can be removed

# %%
data4.shape
# Out:
# (7331, 9)

# %%
data4 = data4[data4.bath<data4.bhk+1]
data4.shape
# Out:
# (6905, 9)

# %%
data4.balcony.unique()
# Out:
# array([2., 3., 1., 0.])

# %%
data4[data4.balcony>2]
# Out:
#                  area_type               location   size  total_sqft  bath  \
# 1           Built-up  Area    Devarabeesana Halli  3 BHK      1750.0   3.0
# 29    Super built-up  Area    1st Block Jayanagar  3 BHK      1875.0   2.0
# 34          Built-up  Area  1st Block Koramangala  2 BHK      1415.0   2.0
# 36    Super built-up  Area  1st Block Koramangala  4 BHK      3000.0   3.0
# 49    Super built-up  Area     1st Phase JP Nagar  3 BHK      1590.0   3.0
# ...                    ...                    ...    ...         ...   ...
# 9053  Super built-up  Area           Yeshwanthpur  3 BHK      1855.0   3.0
# 9062  Super built-up  Area           Yeshwanthpur  3 BHK      1855.0   3.0
# 9074  Super built-up  Area           Yeshwanthpur  3 BHK      1692.0   3.0
# 9081  Super built-up  Area           Yeshwanthpur  3 BHK      1855.0   3.0
# 9082  Super built-up  Area           Yeshwanthpur  3 BHK      1876.0   3.0
#
#       balcony  price  bhk  price_per_sq_fit
# ...

# %%
sns.scatterplot(x="balcony", y="bhk", data=data4)
plt.show()

# %%
plt.hist(x="balcony", data=data4)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='balcony', data=data1)
plt.title('Box Plot of Balcony')
plt.show()

# %%
location_Stats=data4.groupby("location")["location"].agg("count").sort_values(ascending=False)
location_Stats
# Out:
# location
# Whitefield                   182
# Sarjapur  Road               167
# Electronic City              160
# Raja Rajeshwari Nagar        140
# Uttarahalli                  118
#                             ...
# Green Garden Layout            1
# Bhuvaneswari Nagar             1
# Marasandra                     1
# Bhoopsandra                    1
# Chennammanakere Achukattu      1
# Name: location, Length: 745, dtype: int64

# %%
data4.location.value_counts().to_dict()
# Out:
# {'Whitefield': 182,
#  'Sarjapur  Road': 167,
#  'Electronic City': 160,
#  'Raja Rajeshwari Nagar': 140,
#  'Uttarahalli': 118,
#  'Haralur Road': 115,
#  'Marathahalli': 109,
#  'Hennur Road': 105,
#  'Bannerghatta Road': 103,
#  'Electronic City Phase II': 90,
#  'Hebbal': 86,
#  '7th Phase JP Nagar': 85,
#  'Thanisandra': 85,
#  'Yelahanka': 76,
#  'Kanakpura Road': 75,
#  'Bellandur': 71,
#  'KR Puram': 59,
#  'Chandapura': 58,
#  'Sarjapur': 54,
#  'Harlur': 54,
#  'Begur Road': 52,
#  'Kasavanhalli': 51,
#  'Banashankari': 49,
#  'Kothanur': 48,
#  'Rajaji Nagar': 43,
#  'Hormavu': 43,
#  'Electronics City Phase 1': 42,
#  'Hennur': 41,
#  'Varthur': 39,
#  'Akshaya Nagar': 39,
#  'HSR Layout': 39,
#  'Kaggadasapura': 38,
#  'Ramamurthy Nagar': 38,
#  'Kundalahalli': 37,
#  'Hulimavu': 37,
#  'Ramagondanahalli': 36,
#  'Jakkur': 36,
#  'Budigere': 35,
#  '8th Phase JP Nagar': 34,
#  'Koramangala': 34,
#  'Hoodi': 33,
#  'Yeshwanthpur': 33,
#  'Kengeri': 33,
#  'JP Nagar': 33,
# ...

# %%
count_fre_encoding=data4.location.value_counts().to_dict()

# %%
data4.location= data4.location.map(count_fre_encoding)

# %%
data4.shape
# Out:
# (6905, 9)

# %%
data4
# Out:
#                  area_type  location       size  total_sqft  bath  balcony  \
# 0     Super built-up  Area         3      3 BHK      1672.0   3.0      2.0
# 1           Built-up  Area         3      3 BHK      1750.0   3.0      3.0
# 2     Super built-up  Area         3      3 BHK      1750.0   3.0      2.0
# 4     Super built-up  Area        11      2 BHK      1250.0   2.0      2.0
# 5               Plot  Area        11  2 Bedroom      1200.0   2.0      2.0
# ...                    ...       ...        ...         ...   ...      ...
# 9085  Super built-up  Area         1      3 BHK      2900.0   3.0      2.0
# 9086  Super built-up  Area         1      3 BHK      1780.0   3.0      1.0
# 9087            Plot  Area         3  2 Bedroom       880.0   2.0      1.0
# 9088            Plot  Area         3  2 Bedroom      1000.0   2.0      1.0
# 9089            Plot  Area         3  3 Bedroom      1400.0   2.0      1.0
#
#        price  bhk  price_per_sq_fit
# ...

# %%
data4.area_type.unique()
# Out:
# array(['Super built-up  Area', 'Built-up  Area', 'Plot  Area',
#        'Carpet  Area'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data4['area_type_encoded'] = le.fit_transform(data4['area_type'])

# %%
data4
# Out:
#                  area_type  location       size  total_sqft  bath  balcony  \
# 0     Super built-up  Area         3      3 BHK      1672.0   3.0      2.0
# 1           Built-up  Area         3      3 BHK      1750.0   3.0      3.0
# 2     Super built-up  Area         3      3 BHK      1750.0   3.0      2.0
# 4     Super built-up  Area        11      2 BHK      1250.0   2.0      2.0
# 5               Plot  Area        11  2 Bedroom      1200.0   2.0      2.0
# ...                    ...       ...        ...         ...   ...      ...
# 9085  Super built-up  Area         1      3 BHK      2900.0   3.0      2.0
# 9086  Super built-up  Area         1      3 BHK      1780.0   3.0      1.0
# 9087            Plot  Area         3  2 Bedroom       880.0   2.0      1.0
# 9088            Plot  Area         3  2 Bedroom      1000.0   2.0      1.0
# 9089            Plot  Area         3  3 Bedroom      1400.0   2.0      1.0
#
#        price  bhk  price_per_sq_fit  area_type_encoded
# ...

# %%
data4.drop(["area_type","size"], axis=1, inplace=True)
data4
# Out:
#       location  total_sqft  bath  balcony   price  bhk  price_per_sq_fit  \
# 0            3      1672.0   3.0      2.0  150.00    3       8971.291866
# 1            3      1750.0   3.0      3.0  149.00    3       8514.285714
# 2            3      1750.0   3.0      2.0  150.00    3       8571.428571
# 4           11      1250.0   2.0      2.0   40.00    2       3200.000000
# 5           11      1200.0   2.0      2.0   83.00    2       6916.666667
# ...        ...         ...   ...      ...     ...  ...               ...
# 9085         1      2900.0   3.0      2.0  325.00    3      11206.896552
# 9086         1      1780.0   3.0      1.0   84.83    3       4765.730337
# 9087         3       880.0   2.0      1.0   48.00    2       5454.545455
# 9088         3      1000.0   2.0      1.0   55.00    2       5500.000000
# 9089         3      1400.0   2.0      1.0   78.00    3       5571.428571
#
#       area_type_encoded
# 0                     3
# 1                     0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
data4["bath"]=data4["bath"].astype(int)
data4["balcony"]=data4["balcony"].astype(int)
data4["total_sqft"]=data4["total_sqft"].astype(int)

# %%
data4
# Out:
#       location  total_sqft  bath  balcony   price  bhk  price_per_sq_fit  \
# 0            3        1672     3        2  150.00    3       8971.291866
# 1            3        1750     3        3  149.00    3       8514.285714
# 2            3        1750     3        2  150.00    3       8571.428571
# 4           11        1250     2        2   40.00    2       3200.000000
# 5           11        1200     2        2   83.00    2       6916.666667
# ...        ...         ...   ...      ...     ...  ...               ...
# 9085         1        2900     3        2  325.00    3      11206.896552
# 9086         1        1780     3        1   84.83    3       4765.730337
# 9087         3         880     2        1   48.00    2       5454.545455
# 9088         3        1000     2        1   55.00    2       5500.000000
# 9089         3        1400     2        1   78.00    3       5571.428571
#
#       area_type_encoded
# 0                     3
# 1                     0
# ...

# %%
X=data4.drop("price", axis=1)
y=data4["price"]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
ss=StandardScaler()
X_data=ss.fit_transform(X)

#X_train,X_test,y_train,y_test=train_test_split(X_data,y, test_size=0.2, random_state=42)
X_train,X_test, y_train, y_test= train_test_split(X_data, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
# array([[-0.72847996, -0.84230195, -1.64887333, ..., -1.71466539,
#         -0.33250739,  0.55112332],
#        [ 0.60948335,  0.21806811,  0.85700767, ...,  0.64903286,
#          0.02374163,  0.55112332],
#        [ 0.60948335,  0.20530654,  0.85700767, ...,  0.64903286,
#          0.06506564,  0.55112332],
#        ...,
#        [ 1.90690231,  0.143819  ,  0.85700767, ...,  0.64903286,
#         -0.09125456,  0.55112332],
#        [-0.16085917, -0.36664361, -0.39593283, ..., -0.53281627,
#          0.01162202, -0.29907921],
#        [-0.89065733, -0.43625215, -0.39593283, ..., -0.53281627,
#          0.13851004, -1.99948426]])

# %%
X_test
# Out:
# array([[-0.34330871,  0.08581189,  0.85700767, ...,  0.64903286,
#          0.06958066, -0.29907921],
#        [-0.50548608, -0.35504219, -0.39593283, ..., -0.53281627,
#          0.17010267, -1.99948426],
#        [-0.85011299, -0.2622308 , -0.39593283, ..., -0.53281627,
#         -0.53355141,  0.55112332],
#        ...,
#        [-0.26222002, -0.62999591, -0.39593283, ..., -0.53281627,
#         -0.11165495, -1.99948426],
#        [-0.26222002, -0.27963294, -0.39593283, ..., -0.53281627,
#          0.23041588,  0.55112332],
#        [-0.42439739,  0.33524248,  0.85700767, ...,  0.64903286,
#          0.35326961,  0.55112332]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr_model=lr.fit(X_train, y_train)

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.7985965750608484

# %% [raw]
# Use K Fold cross validation to measure accuracy of our LinearRegression model

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.83425856, 0.86092512, 0.87573461, 0.75453428, 0.83580098])

# %% [raw]
# We can see that in 5 iterations we get a score above 79 all the time. This is pretty good but we want to test few other algorithms for regression to see if we can get even better score

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit

# Create a list of regression models
models = [
    LinearRegression(),
    LogisticRegression(),
    DecisionTreeRegressor(),
    RandomForestRegressor(),
    KNeighborsClassifier(),
    SVR(),
    GradientBoostingRegressor(),
]

# Create a dictionary to store the model names and their respective scores
model_scores = {}

# Define cross-validation settings
cv = ShuffleSplit(n_splits=9, test_size=0.3, random_state=42)

# Iterate through each model and calculate its cross-validation score
for model in models:
    model_name = model.__class__.__name__
    scores = cross_val_score(model, X, y, cv=cv)
    mean_score = np.mean(scores)
    model_scores[model_name] = mean_score

# Display the model scores
for model_name, score in model_scores.items():
    print(f"{model_name}: {score}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7804\3707638045.py in <module>
#      28 for model in models:
#      29     model_name = model.__class__.__name__
# ---> 30     scores = cross_val_score(model, X, y, cv=cv)
#      31     mean_score = np.mean(scores)
#      32     model_scores[model_name] = mean_score
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     513     scorer = check_scoring(estimator, scoring=scoring)
#     514
# --> 515     cv_results = cross_validate(
#     516         estimator=estimator,
#     517         X=X,
#
# ...

# %% [raw]
# By the above result we found GradientBoostingRegressor with 94% score for our model so for our model we use GradientBoostingRegressor

# %%
gr=GradientBoostingRegressor()
gr_model=gr.fit(X_train, y_train)
gr_model.score(X_test, y_test)
# Out:
# 0.9436046737100517

# %%
import joblib

# Save the model and preprocessing objects
joblib.dump(gr_model, 'real_estate_model.pkl')
joblib.dump(lr, "area_type_encoder.pkl")
# Out:
# ['area_type_encoder.pkl']
